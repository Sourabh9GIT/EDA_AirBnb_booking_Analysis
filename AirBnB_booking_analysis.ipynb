# %% [markdown]
# <a href="https://colab.research.google.com/github/Sourabh9GIT/EDA_AirBnb_booking_Analysis/blob/main/AirBnB_booking_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name**            - Sourabh Patil

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Since 2008, guests and hosts have used Airbnb to expand on travelling possibilities and present a more unique, personalised way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analysed and used for security, business decisions, understanding of customers' and providers' (hosts) behaviour and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more. This dataset has around 49,000 observations in it with 16 columns and it is a mix of categorical and numeric values. Explore and analyse the data to discover key understandings.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Link: https://github.com/Sourabh9GIT/EDA_AirBnb_booking_Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Explore & analyze the data to discover key understanding such as:
#
#
#
# *   What can we learn about different hosts and areas?
# *   What can we learn from prediction such as location, reviews,prices etc?
#
# *   which hosts are busiest & why?
# *   Is there any noticeble differnce of traffic among in various areas & what is the reason behind for that?

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset First View

# %%
df=pd.read_csv('/content/drive/MyDrive/Airbnb NYC 2019.csv')
df.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# ### Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# #### Duplicate Values

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# #### Missing Values/Null Values

# %%
df.reviews_per_month.fillna(value=0, inplace = True)

# %%
df['last_review']=pd.to_datetime(df['last_review'], format = '%Y-%m-%d')
df.last_review = df['last_review'].dt.year.astype('object')
df.last_review.fillna(value = 'Never', inplace= True)

# %%
df.isnull().sum()
# Out:
# id                                 0
# name                              16
# host_id                            0
# host_name                         21
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# last_review                        0
# reviews_per_month                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# # Observation:
#
#
#
# *   These dataset has total 48895 rows and 16 columns.
#
#
# *   The Average price is 125 usd.
# *   On average, people stay in a room for 7 days.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# # Analyze:

# %% [markdown]
# ## 1. Room type v/s No of people

# %%
a= sns.boxenplot(data=df, x="room_type", y="calculated_host_listings_count")
a.set_title('Room Type v/s Number Of People Staying')
a.set_ylabel('Number of occupants')
a.set_xlabel('Types of rooms')
# Out:
# Text(0.5, 0, 'Types of rooms')

# %% [markdown]
# # Observation
# when the number people is higher, bigger rooms are booked.

# %% [markdown]
# #2.  Types of room in each location

# %%
a=sns.countplot(data=df, x="neighbourhood_group", hue="room_type")
a.set_title('TYPES OF ROOM IN EVERY NEIGHBOURHOOD')
a.set_ylabel('Number of hotels')
a.set_xlabel('Neighbourhood')
# Out:
# Text(0.5, 0, 'Neighbourhood')

# %% [markdown]
# # Observation:
#
#
# *   The majority of rooms in the dataset are classified as"Entire home/apt"type.
# *   Shared rooms have the lowest count in dataset
#
# *   This observation suggests that there is a higher demand for rooms of the "Entire home/apt"type.

# %% [markdown]
# ### 3. Types of room & then mean prices per person

# %%
df2=df.groupby(['room_type'],as_index=False).agg({'price':"mean","calculated_host_listings_count":"mean"})
df2['avg. pay per person']= df2['price']/df2['calculated_host_listings_count']
a=sns.barplot(data=df2, x="room_type",y="avg. pay per person")
a.set_title('AVERAGE PRICE OF ROOM PER PERSON')
a.set_ylabel('Price')
a.set_xlabel('Types of rooms')
# Out:
# Text(0.5, 0, 'Types of rooms')

# %% [markdown]
# # observation:
#
#
# *   Shared rooms are the most affordable per person.
# *   Private rooms are the most expensive per person.

# %% [markdown]
# ### 4.  Avg. time stay in each type of room

# %%
df3=df.groupby(['room_type'],as_index=False).agg({'minimum_nights':"mean"}).sort_values(by='minimum_nights')
a=sns.barplot(data=df3, x="room_type", y="minimum_nights")
a.set_title('AVERAGE TIME OF STAY IN EACH TYPE OF ROOM')
a.set_ylabel('Nights stayed')
a.set_xlabel('Types of rooms')
# Out:
# Text(0.5, 0, 'Types of rooms')

# %% [markdown]
# # Observation:
#
#
# *   People who book Entire home/apt stay longer as compared to people who book private room.

# %% [markdown]
# ## 5. Hotels used every year

# %%
df4=df.groupby(['last_review'],as_index=False).count()
df4.drop([9],axis=0,inplace=True)
df4

a=sns.lineplot(data=df4, x="last_review", y='id')
a.set_title('HOTELS BOOKED EACH YEAR')
a.set_ylabel('Year')
a.set_xlabel('Count of hotel booked')
# Out:
# Text(0.5, 0, 'Count of hotel booked')

# %% [markdown]
# # Observation:
#
#
# *   The usage of hotel as significantly increased in last few years.
# *   The trend tell us that popularity of Airbnb has seen steady increase from 2011.

# %% [markdown]
# # 6. No of nights v/s No of reviews

# %%
fig, ax = plt.subplots(figsize=(12,8))
a=sns.scatterplot(data=df, x="minimum_nights", y="number_of_reviews")
a.set_title('NUMBER OF DAYS STAYED v/s NUMBER OF REVIWS')
a.set_ylabel('Night stayed')
a.set_xlabel('Number of reviews')
# Out:
# Text(0.5, 0, 'Number of reviews')

# %% [markdown]
# # Observation:
#
#
# *   As number of nights to stay increase, number of review decrease.
# *   lower of no of night stays , highest reviews

# %% [markdown]
# # 7. AirBnb most liked by people

# %%
df1= df.groupby(['name'],as_index=False).count().nlargest(5,'host_id')
df1= df1[:5]
a=sns.barplot(x='name', y='id', data=df1)
a.set_title('MOST LIKED AIRBNB')
a.set_ylabel('No. of bookings')
a.set_xlabel('Hotel')
a.set_xticklabels(a.get_xticklabels(),rotation=60);
plt.show()

# %% [markdown]
# # 8. Number of available rooms in different neighbourhood

# %%
f,ax = plt.subplots(figsize=(16,8))
ax = sns.scatterplot(y=df.latitude,x=df.longitude,hue=df.neighbourhood_group,palette="rainbow")
plt.show()

# %% [markdown]
# # Observation:
#
# we can see that hotel rooms are more densely populated in brooklyn & are a lot more spred in queens.

# %% [markdown]
# # 9. Distribution of types of rooms in different neighbourhood groups

# %%
f, ax = plt.subplots(figsize=(16,8))
ax = sns.scatterplot(y=df.latitude,x=df.longitude, hue=df.room_type,palette='bright')
ax.set_title('Distrubution of types of rooms in different neighbourhood groups')
plt.show()

# %% [markdown]
# # Observation
#
#
# *   The latitude & longitude data visualizatilon,it becomes apperent that brookyln & manhatten exhibit the highest density of rooms.
#
# *   These two followed closely by Queens island in terms of accomodation density

# %% [markdown]
# # 10. Average price for each type of room per neighbourhood

# %%
df1=df.groupby(['room_type','neighbourhood_group'])['price'].mean().sort_values(ascending=True).reset_index()
f,ax = plt.subplots(figsize=(16,8))
ax = sns.barplot(x="neighbourhood_group",y="price",hue="room_type",data=df1)

ax.set_title('Average price for each type of room per neighbourhood')
ax.set_ylabel('Avg price $')
ax.set_xlabel('Neighbourhood')
plt.show()

# %% [markdown]
# # Observation:
#
#
# *   Brooklyn offers affordable shared rooms option.
# *   Entire Home/Apartments type stays are more expensive compared to other 2 types
#
# *   The Average price for a private room in manhatten is notably high, so that is relatively expensive

# %%
df1
# Out:
#           room_type neighbourhood_group       price
# 0       Shared room            Brooklyn   50.527845
# 1       Shared room       Staten Island   57.444444
# 2       Shared room               Bronx   59.800000
# 3      Private room       Staten Island   62.292553
# 4      Private room               Bronx   66.788344
# 5       Shared room              Queens   69.020202
# 6      Private room              Queens   71.762456
# 7      Private room            Brooklyn   76.500099
# 8       Shared room           Manhattan   88.977083
# 9      Private room           Manhattan  116.776622
# 10  Entire home/apt               Bronx  127.506596
# 11  Entire home/apt              Queens  147.050573
# 12  Entire home/apt       Staten Island  173.846591
# 13  Entire home/apt            Brooklyn  178.327545
# 14  Entire home/apt           Manhattan  249.239109

# %% [markdown]
# # 11. Top 20 most expensive neighbourhood

# %%
df4= df.groupby("neighbourhood")["price"].mean().sort_values(ascending=False).reset_index().head(20)
df4

f,ax = plt.subplots(figsize=(16,8))
ax = sns.barplot(x="neighbourhood",y="price",data=df4)

ax.set_title('Top 20 most expensive neighbourhood')
ax.set_ylabel('Avg price')
ax.set_xlabel('Neighbourhood')
ax.set_xticklabels(ax.get_xticklabels(),rotation=80);
plt.show()

# %% [markdown]
# #Observation:
# Fort wadsworth tops the list of the 20 most expensive locality in NYC

# %% [markdown]
# # 12. Top 20 least expensive neighbourhood

# %%
df4_1= df.groupby("neighbourhood")["price"].mean().sort_values(ascending=False).reset_index().tail(20)


f,ax = plt.subplots(figsize=(16,8))
ax = sns.barplot(x="neighbourhood",y="price",data=df4_1)

ax.set_title('Top 20 least expensive neighbourhood')
ax.set_ylabel('Avg price')
ax.set_xlabel('Neighbourhood')
ax.set_xticklabels(ax.get_xticklabels(),rotation=80);
plt.show()

# %% [markdown]
# # Observation:
# Bull head is the least expensive based on mean price

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# • The cost of accommodations in Staten Island is generally lower compared to Manhattan. Shared Rooms in Staten Island are available at a significantly cheaper rate, starting from 21 USD per night, while in Manhattan, the highest price for a Shared Room reaches 88 USD per night.
#
# • Private Rooms have a higher cost compared to Shared Rooms, with prices above 50 USD per night regardless of location.
#
# • Manhattan receives the highest number of reviews, indicating its popularity among visitors or guests. On the other hand, Staten Island has a lower review count, suggesting it is less popular in comparison.
#
#
# • Pricing trends fluctuate throughout the year to align with presumed demand. Prices tend to increase during peak seasons or holidays and fluctuate to remain competitive.
#
# • Apartments/Entire homes are the most expensive option, exceeding 100 USD per night.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
